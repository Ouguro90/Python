# %% [markdown]
# ## 1. 평균 점수 구하기

# %%
kor = 80
eng = 75
math = 55

total_score = (kor + eng + 55) / 3
print(total_score)
# Out:
# 70.0

# %% [markdown]
# ## 2. 홀수, 짝수 판별하기
#
# 자연수 13이 홀수인지, 짝수인지 판별할 수 있는 방법

# %%
a = 13

if a % 2:
  print('짝수')
else:
  print('홀수')
# Out:
# 짝수

# %% [markdown]
# ## 3. 주민등록번호 나누기
#
# 주민등록번호를 연월일 부분과 그 뒤의 숫자 부분으로 나누어 출력

# %%
pin = '881120-1068234'

yyyymmdd = pin[:6]
num = pin[7:]

print(yyyymmdd)
print(num)
# Out:
# 881120
# 1068234

# %% [markdown]
# ## 4. 주민등록번호 인덱싱
#
# 주민등록번호 뒷자리의 맨 첫 번째 숫자는 성별을 나타낸다
# 주민등록번호에서 성별을 나타내는 숫자를 출력

# %%
pin = '881120-1068234'
print(pin[7])
# Out:
# 1

# %% [markdown]
# ## 5. 문자열 바꾸기
#
# a:b:c:d 문자열을 replace를 사용해 a#b#c#d로 바꿔 출력

# %%
a = 'a:b:c:d'
b = a.replace(':', '#')
print(b)
# Out:
# a#b#c#d

# %% [markdown]
# ## 6. 리스트 역순 정렬하기
#
# [1,3,5,4,2] 리스트를 [5,4,3,2,1]로 만들기

# %%
a = [1, 3, 5, 4, 2]
a.sort()
a.reverse()

print(a)
# Out:
# [5, 4, 3, 2, 1]

# %% [markdown]
# ## 7. 리스트를 문자열로 만들기
#
# ['Life','is','too','short'] 리스트를 Life is too short 문자열로 만들어 출력

# %%
a = ['Life', 'is', 'too', 'short']

result = ' '.join(a)

print(result)
# Out:
# Life is too short

# %% [markdown]
# ## 8. 튜플 더하기
#
# (1, 2, 3) 튜플에 값 4를 추가하여 (1, 2, 3, 4)를 만든 후 출력

# %%
a = (1, 2, 3)
a = a + (4,)
print(a)
# Out:
# (1, 2, 3, 4)

# %% [markdown]
# ## 9. 딕셔너리의 키
#
# 다음과 같은 딕셔너리 a가 있다
#
# ```python
# a = dict()
# a
# ```
#
# 다음 중 오류가 발생하는 경우를 고르고, 그 이유를 설명
#
# a['name'] = 'python'
# a[('a',)] = 'python'
# a[[1]] = 'python'
# a[250] = 'python'

# %%
a = dict()
a

a[[1]] = 'python'
# 리스트를 딕셔너리의 키로 사용하려해서 에러
# 리스트는 변경 가능하기 때문에 내부의 값이 언제든지 변경될 수 있다
# 값이 변할 경우 고유한 해시값이 달라질 수 있기 때문에 리스트와 같은 자료형은 해시값을 가질 수 없다
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-e90295fbc01e> in <cell line: 0>()
#       2 a
#       3
# ----> 4 a[[1]] = 'python'
#
# TypeError: unhashable type: 'list'

# %% [markdown]
# ## 10. 딕셔너리 값 추출

# %%
a = {'A':90, 'B':80, 'C':70}
result = a.pop('B')

print(a)
print(result)
# Out:
# {'A': 90, 'C': 70}
# 80

# %% [markdown]
# ## 11. 리스트에서 중복 제거

# %%
a = [1, 1, 1, 2, 2, 3, 3, 3, 4, 4, 5]
aSet = set(a)
b = list(aSet)
print(b)
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# ## 12. 파이썬 변수
# a, b 변수를 선언한 후 두 번째 요솟값을 변경하면 b 값이 어떻게 변경되는지와
# 이런 결과가 나타나는 이유를 설명

# %%
a = b = [1, 2, 3]
a[1] = 4
print(b)
# Out:
# [1, 4, 3]

# %% [markdown]
# b값도 마찬가지로 변경된다
# a와 b가 가르키는 리스트가 동일하기 때문에
# a만 변경해도 b까지 변경된다
